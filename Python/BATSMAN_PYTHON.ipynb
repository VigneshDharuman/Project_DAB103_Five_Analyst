# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
battingdf = pd.read_csv ('D:/St Clair/Lab 103/PROJECT2/all_season_batting_card.csv')
print(battingdf)
# Out:
#        season  match_id match_name home_team away_team  \
# 0        2020   1216492   MI v CSK        MI       CSK
# 1        2020   1216492   MI v CSK        MI       CSK
# 2        2020   1216492   MI v CSK        MI       CSK
# 3        2020   1216492   MI v CSK        MI       CSK
# 4        2020   1216492   MI v CSK        MI       CSK
# ...       ...       ...        ...       ...       ...
# 12424    2008    336040   CSK v RR       CSK        RR
# 12425    2008    336040   CSK v RR       CSK        RR
# 12426    2008    336040   CSK v RR       CSK        RR
# 12427    2008    336040   CSK v RR       CSK        RR
# 12428    2008    336040   CSK v RR       CSK        RR
#
#                                     venue       city               country  \
# 0         Sheikh Zayed Stadium, Abu Dhabi  Abu Dhabi  United Arab Emirates
# 1         Sheikh Zayed Stadium, Abu Dhabi  Abu Dhabi  United Arab Emirates
# 2         Sheikh Zayed Stadium, Abu Dhabi  Abu Dhabi  United Arab Emirates
# ...

# %%
battingdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12429 entries, 0 to 12428
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season           12429 non-null  int64
#  1   match_id         12429 non-null  int64
#  2   match_name       12429 non-null  object
#  3   home_team        12429 non-null  object
#  4   away_team        12429 non-null  object
#  5   venue            12429 non-null  object
#  6   city             12429 non-null  object
#  7   country          12429 non-null  object
#  8   current_innings  12429 non-null  object
#  9   innings_id       12429 non-null  int64
#  10  name             12429 non-null  object
#  11  fullName         12429 non-null  object
#  12  runs             12423 non-null  float64
#  13  ballsFaced       12423 non-null  float64
#  14  minutes          12423 non-null  object
#  15  fours            12423 non-null  float64
# ...

# %%
battingdf.describe()
# Out:
#              season      match_id    innings_id          runs    ballsFaced  \
# count  12429.000000  1.242900e+04  12429.000000  12423.000000  12423.000000
# mean    2013.892831  7.537903e+05      1.488937     19.314578     15.101827
# std        3.665588  3.059846e+05      0.499898     21.042234     13.611837
# min     2008.000000  3.359820e+05      1.000000      0.000000      0.000000
# 25%     2011.000000  5.012250e+05      1.000000      3.000000      5.000000
# 50%     2014.000000  7.292930e+05      1.000000     12.000000     11.000000
# 75%     2017.000000  1.082626e+06      2.000000     28.000000     22.000000
# max     2020.000000  1.237181e+06      2.000000    175.000000     73.000000
#
#               fours         sixes  runningOver  link
# count  12423.000000  12423.000000  9484.000000   0.0
# mean       1.762779      0.715930    11.375812   NaN
# std        2.287568      1.303937     6.012209   NaN
# min        0.000000      0.000000     0.100000   NaN
# ...

# %%
battingdf.isnull().sum()
# Out:
# season                 0
# match_id               0
# match_name             0
# home_team              0
# away_team              0
# venue                  0
# city                   0
# country                0
# current_innings        0
# innings_id             0
# name                   0
# fullName               0
# runs                   6
# ballsFaced             6
# minutes                6
# fours                  6
# sixes                  6
# strikeRate             6
# captain                0
# isNotOut               6
# runningScore           6
# runningOver         2945
# shortText              0
# commentary          2948
# link               12429
# dtype: int64

# %%
battingdf.drop(['link','commentary','shortText','runningOver','runningScore','isNotOut','captain','minutes','match_name','fullName'],axis=1, inplace =True)

# %%
battingdf.rename(columns={'season':'Season','match_id':'Match_ID','home_team':'Home_Team','away_team':'Away_Team','venue':'Venue','city':'City','country':'Country','current_innings':'Current_Innings','innings_id':'Innings_ID','name':'Player','runs':'Runs','ballsFaced':'Balls_Faced','fours':'Fours','sixes':'Sixes','strikeRate':'Strike_Rate'}, inplace=True)

# %%
battingdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12429 entries, 0 to 12428
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Season           12429 non-null  int64
#  1   Match_ID         12429 non-null  int64
#  2   Home_Team        12429 non-null  object
#  3   Away_Team        12429 non-null  object
#  4   Venue            12429 non-null  object
#  5   City             12429 non-null  object
#  6   Country          12429 non-null  object
#  7   Current_Innings  12429 non-null  object
#  8   Innings_ID       12429 non-null  int64
#  9   Player           12429 non-null  object
#  10  Runs             12423 non-null  float64
#  11  Balls_Faced      12423 non-null  float64
#  12  Fours            12423 non-null  float64
#  13  Sixes            12423 non-null  float64
#  14  Strike_Rate      12423 non-null  object
# dtypes: float64(4), int64(3), object(8)
# memory usage: 1.4+ MB

# %%
battingdf.head(5)
# Out:
#    Season  Match_ID Home_Team Away_Team                            Venue  \
# 0    2020   1216492        MI       CSK  Sheikh Zayed Stadium, Abu Dhabi
# 1    2020   1216492        MI       CSK  Sheikh Zayed Stadium, Abu Dhabi
# 2    2020   1216492        MI       CSK  Sheikh Zayed Stadium, Abu Dhabi
# 3    2020   1216492        MI       CSK  Sheikh Zayed Stadium, Abu Dhabi
# 4    2020   1216492        MI       CSK  Sheikh Zayed Stadium, Abu Dhabi
#
#         City               Country Current_Innings  Innings_ID     Player  \
# 0  Abu Dhabi  United Arab Emirates              MI           1  RG Sharma
# 1  Abu Dhabi  United Arab Emirates              MI           1  Q de Kock
# 2  Abu Dhabi  United Arab Emirates              MI           1   SA Yadav
# 3  Abu Dhabi  United Arab Emirates              MI           1  SS Tiwary
# 4  Abu Dhabi  United Arab Emirates              MI           1  HH Pandya
#
#    Runs  Balls_Faced  Fours  Sixes Strike_Rate
# ...

# %%
battingdf.to_csv("Batting_stats.csv")
