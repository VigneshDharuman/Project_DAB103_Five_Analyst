# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import base64
from IPython.display import HTML
import matplotlib.pyplot as plt

# %% [raw]
# Importing csv file:

# %%
bowl = pd.read_csv (r'C:\Users\91739\Downloads\IPL_data_bowling.csv')
bowl
# Out:
#       season  match_id match_name home_team away_team bowling_team  \
# 0       2020   1216492   MI v CSK        MI       CSK          CSK
# 1       2020   1216492   MI v CSK        MI       CSK          CSK
# 2       2020   1216492   MI v CSK        MI       CSK          CSK
# 3       2020   1216492   MI v CSK        MI       CSK          CSK
# 4       2020   1216492   MI v CSK        MI       CSK          CSK
# ...      ...       ...        ...       ...       ...          ...
# 9662    2008    336040   CSK v RR       CSK        RR          CSK
# 9663    2008    336040   CSK v RR       CSK        RR          CSK
# 9664    2008    336040   CSK v RR       CSK        RR          CSK
# 9665    2008    336040   CSK v RR       CSK        RR          CSK
# 9666    2008    336040   CSK v RR       CSK        RR          CSK
#
#                                    venue       city               country  \
# 0        Sheikh Zayed Stadium, Abu Dhabi  Abu Dhabi  United Arab Emirates
# ...

# %% [raw]
# Checking null Values:

# %%
bowl.isnull()
# Out:
#       season  match_id  match_name  home_team  away_team  bowling_team  venue  \
# 0      False     False       False      False      False         False  False
# 1      False     False       False      False      False         False  False
# 2      False     False       False      False      False         False  False
# 3      False     False       False      False      False         False  False
# 4      False     False       False      False      False         False  False
# ...      ...       ...         ...        ...        ...           ...    ...
# 9662   False     False       False      False      False         False  False
# 9663   False     False       False      False      False         False  False
# 9664   False     False       False      False      False         False  False
# 9665   False     False       False      False      False         False  False
# 9666   False     False       False      False      False         False  False
#
# ...

# %% [raw]
# Number of null values:

# %%
bowl.isnull().sum()
# Out:
# season           0
# match_id         0
# match_name       0
# home_team        0
# away_team        0
# bowling_team     0
# venue            0
# city             0
# country          0
# innings_id       0
# name             0
# fullName         0
# overs            0
# maidens          0
# conceded         0
# wickets          0
# economyRate      1
# dots             0
# foursConceded    0
# sixesConceded    0
# wides            0
# noballs          0
# captain          0
# href             0
# dtype: int64

# %%
missing_value=["N/a","Na","Null","na",np.nan]
bowl = pd.read_csv (r'C:\Users\91739\Downloads\IPL_data_bowling.csv',na_values=missing_value)

# %%
bowl.isnull().sum()
# Out:
# season           0
# match_id         0
# match_name       0
# home_team        0
# away_team        0
# bowling_team     0
# venue            0
# city             0
# country          0
# innings_id       0
# name             0
# fullName         0
# overs            0
# maidens          0
# conceded         0
# wickets          0
# economyRate      1
# dots             0
# foursConceded    0
# sixesConceded    0
# wides            0
# noballs          0
# captain          0
# href             0
# dtype: int64

# %%
bowl.isnull().any()
# Out:
# season           False
# match_id         False
# match_name       False
# home_team        False
# away_team        False
# bowling_team     False
# venue            False
# city             False
# country          False
# innings_id       False
# name             False
# fullName         False
# overs            False
# maidens          False
# conceded         False
# wickets          False
# economyRate       True
# dots             False
# foursConceded    False
# sixesConceded    False
# wides            False
# noballs          False
# captain          False
# href             False
# dtype: bool

# %%
bowl.dropna()
# Out:
#       season  match_id match_name home_team away_team bowling_team  \
# 0       2020   1216492   MI v CSK        MI       CSK          CSK
# 1       2020   1216492   MI v CSK        MI       CSK          CSK
# 2       2020   1216492   MI v CSK        MI       CSK          CSK
# 3       2020   1216492   MI v CSK        MI       CSK          CSK
# 4       2020   1216492   MI v CSK        MI       CSK          CSK
# ...      ...       ...        ...       ...       ...          ...
# 9662    2008    336040   CSK v RR       CSK        RR          CSK
# 9663    2008    336040   CSK v RR       CSK        RR          CSK
# 9664    2008    336040   CSK v RR       CSK        RR          CSK
# 9665    2008    336040   CSK v RR       CSK        RR          CSK
# 9666    2008    336040   CSK v RR       CSK        RR          CSK
#
#                                    venue       city               country  \
# 0        Sheikh Zayed Stadium, Abu Dhabi  Abu Dhabi  United Arab Emirates
# ...

# %%
bowl
# Out:
#       season  match_id match_name home_team away_team bowling_team  \
# 0       2020   1216492   MI v CSK        MI       CSK          CSK
# 1       2020   1216492   MI v CSK        MI       CSK          CSK
# 2       2020   1216492   MI v CSK        MI       CSK          CSK
# 3       2020   1216492   MI v CSK        MI       CSK          CSK
# 4       2020   1216492   MI v CSK        MI       CSK          CSK
# ...      ...       ...        ...       ...       ...          ...
# 9662    2008    336040   CSK v RR       CSK        RR          CSK
# 9663    2008    336040   CSK v RR       CSK        RR          CSK
# 9664    2008    336040   CSK v RR       CSK        RR          CSK
# 9665    2008    336040   CSK v RR       CSK        RR          CSK
# 9666    2008    336040   CSK v RR       CSK        RR          CSK
#
#                                    venue       city               country  \
# 0        Sheikh Zayed Stadium, Abu Dhabi  Abu Dhabi  United Arab Emirates
# ...

# %%
bowl.dropna(how='all')
# Out:
#       season  match_id match_name home_team away_team bowling_team  \
# 0       2020   1216492   MI v CSK        MI       CSK          CSK
# 1       2020   1216492   MI v CSK        MI       CSK          CSK
# 2       2020   1216492   MI v CSK        MI       CSK          CSK
# 3       2020   1216492   MI v CSK        MI       CSK          CSK
# 4       2020   1216492   MI v CSK        MI       CSK          CSK
# ...      ...       ...        ...       ...       ...          ...
# 9662    2008    336040   CSK v RR       CSK        RR          CSK
# 9663    2008    336040   CSK v RR       CSK        RR          CSK
# 9664    2008    336040   CSK v RR       CSK        RR          CSK
# 9665    2008    336040   CSK v RR       CSK        RR          CSK
# 9666    2008    336040   CSK v RR       CSK        RR          CSK
#
#                                    venue       city               country  \
# 0        Sheikh Zayed Stadium, Abu Dhabi  Abu Dhabi  United Arab Emirates
# ...

# %%
bowl.interpolate()
# Out:
#       season  match_id match_name home_team away_team bowling_team  \
# 0       2020   1216492   MI v CSK        MI       CSK          CSK
# 1       2020   1216492   MI v CSK        MI       CSK          CSK
# 2       2020   1216492   MI v CSK        MI       CSK          CSK
# 3       2020   1216492   MI v CSK        MI       CSK          CSK
# 4       2020   1216492   MI v CSK        MI       CSK          CSK
# ...      ...       ...        ...       ...       ...          ...
# 9662    2008    336040   CSK v RR       CSK        RR          CSK
# 9663    2008    336040   CSK v RR       CSK        RR          CSK
# 9664    2008    336040   CSK v RR       CSK        RR          CSK
# 9665    2008    336040   CSK v RR       CSK        RR          CSK
# 9666    2008    336040   CSK v RR       CSK        RR          CSK
#
#                                    venue       city               country  \
# 0        Sheikh Zayed Stadium, Abu Dhabi  Abu Dhabi  United Arab Emirates
# ...

# %% [raw]
# DATA TRANSFORMATION

# %%
bowl.drop('href', axis=1, inplace=True)

# %%
bowl
# Out:
#       season  match_id match_name home_team away_team bowling_team  \
# 0       2020   1216492   MI v CSK        MI       CSK          CSK
# 1       2020   1216492   MI v CSK        MI       CSK          CSK
# 2       2020   1216492   MI v CSK        MI       CSK          CSK
# 3       2020   1216492   MI v CSK        MI       CSK          CSK
# 4       2020   1216492   MI v CSK        MI       CSK          CSK
# ...      ...       ...        ...       ...       ...          ...
# 9662    2008    336040   CSK v RR       CSK        RR          CSK
# 9663    2008    336040   CSK v RR       CSK        RR          CSK
# 9664    2008    336040   CSK v RR       CSK        RR          CSK
# 9665    2008    336040   CSK v RR       CSK        RR          CSK
# 9666    2008    336040   CSK v RR       CSK        RR          CSK
#
#                                    venue       city               country  \
# 0        Sheikh Zayed Stadium, Abu Dhabi  Abu Dhabi  United Arab Emirates
# ...

# %% [raw]
# Downloading Transformed CSV

# %%
bowl.to_csv(r'C:\Users\91739\Downloads\bowling2.csv')
